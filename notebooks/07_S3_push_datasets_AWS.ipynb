# %%
import boto3
s3 = boto3.client('s3')
response = s3.list_buckets()
print(response)
# Out:
# {'ResponseMetadata': {'RequestId': 'Y7QDER5RWRFC1YNC', 'HostId': 'wph8zOQeJAqb4rTD9SAliLVDLhL5D561AFZLXxGssI6gT6EcCO/zhz/VVM9cVGOGzB32flVKMgk=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'wph8zOQeJAqb4rTD9SAliLVDLhL5D561AFZLXxGssI6gT6EcCO/zhz/VVM9cVGOGzB32flVKMgk=', 'x-amz-request-id': 'Y7QDER5RWRFC1YNC', 'date': 'Wed, 14 Jan 2026 03:07:28 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'Buckets': [{'Name': 'elasticbeanstalk-us-east-1-179363955835', 'CreationDate': datetime.datetime(2024, 10, 11, 4, 10, 54, tzinfo=tzutc()), 'BucketArn': 'arn:aws:s3:::elasticbeanstalk-us-east-1-179363955835'}, {'Name': 'housing-price-regressor', 'CreationDate': datetime.datetime(2026, 1, 14, 3, 6, 29, tzinfo=tzutc()), 'BucketArn': 'arn:aws:s3:::housing-price-regressor'}], 'Owner': {'ID': 'ff9c91fc37aa95e56a2b03f95f2bf7e768a7dd534b3641d61562b902baccdf7b'}}

# %%
import boto3
from pathlib import Path

# ---- Config ----
bucket = "housing-price-regressor"   # replace with your bucket name
region = "us-east-1"                 # your AWS region

# Set project root as parent of the notebooks folder
PROJECT_ROOT = Path.cwd().parent
local_data_dir = PROJECT_ROOT / "data" / "processed"
local_model_dir = PROJECT_ROOT / "models"

s3 = boto3.client("s3", region_name=region)

# ---- Helper function ----
def upload_file(local_path: Path, s3_key: str):
    if not local_path.exists():
        print(f"❌ File not found: {local_path}")
        return
    print(f"⬆️ Uploading {local_path} → s3://{bucket}/{s3_key}")
    s3.upload_file(str(local_path), bucket, s3_key)

# ---- Upload required datasets ----
upload_file(local_data_dir / "feature_engineered_holdout.csv", "processed/feature_engineered_holdout.csv")
upload_file(local_data_dir / "cleaning_holdout.csv", "processed/cleaning_holdout.csv")
upload_file(local_data_dir / "feature_engineered_train.csv", "processed/feature_engineered_train.csv")

# ---- Upload model ----
upload_file(local_model_dir / "xgb_best_model.pkl", "models/xgb_best_model.pkl")
# Out:
# ⬆️ Uploading /Users/kalpitpatel/CascadeProjects/housing-price-regressor/data/processed/feature_engineered_holdout.csv → s3://housing-price-regressor/processed/feature_engineered_holdout.csv
# ⬆️ Uploading /Users/kalpitpatel/CascadeProjects/housing-price-regressor/data/processed/cleaning_holdout.csv → s3://housing-price-regressor/processed/cleaning_holdout.csv
# ⬆️ Uploading /Users/kalpitpatel/CascadeProjects/housing-price-regressor/data/processed/feature_engineered_train.csv → s3://housing-price-regressor/processed/feature_engineered_train.csv
# ⬆️ Uploading /Users/kalpitpatel/CascadeProjects/housing-price-regressor/models/xgb_best_model.pkl → s3://housing-price-regressor/models/xgb_best_model.pkl
